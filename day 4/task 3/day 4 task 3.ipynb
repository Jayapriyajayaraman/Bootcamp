# %%
import pandas as pd  
df = pd.read_csv("telco_customer_churn.csv")

# %%
df.dropna(inplace=True)

# %%
plt.hist(df["Monthly Charge"], bins=30, color="skyblue", edgecolor="black")  
plt.title("Distribution of Monthly Charges")  
plt.xlabel("Monthly Charges")  
plt.ylabel("Customer Count")  
plt.show()

# %%
plt.scatter(df["Monthly Charge"], df["Total Charges"], alpha=0.5, c=df["Churn Score"], cmap="coolwarm")  
plt.title("Monthly Charges vs. Total Charges")  
plt.xlabel("Monthly Charges")  
plt.ylabel("Total Charges")  
plt.colorbar(label="Churn Score")  
plt.show()

# %%
sns.countplot(x=df["Contract"], hue=df["Contract"], palette="coolwarm", legend=False)  
plt.title("Customer Count by Contract Type")  
plt.show()
